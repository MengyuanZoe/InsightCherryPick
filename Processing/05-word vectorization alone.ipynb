# %%
#basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#function libraries
import load_data_utils
import parse_comments_utils
import features_utils
import classifier_utils
import plot_utils
from sklearn.model_selection import train_test_split
# Out:
# /anaconda/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
features = pd.read_pickle('./features')
labels = pd.read_pickle('./labels')

# %% [markdown]
# # SPLIT training, validation, testing set & SMOTE training set

# %%
X = features.as_matrix(features.columns[8:58])
Y = labels['purchase_intent'].astype(int)
Ym = labels['label'].astype(int)

#divide into trainig, validation & testing
#binary
X_trainfull, X_test, y_trainfull, y_test = train_test_split(X, Y, test_size=0.2, random_state=13)
X_train, X_valid, y_train, y_valid = train_test_split(X_trainfull, y_trainfull, test_size = 0.2, random_state = 13)
print('binary, number of samples per class before SMOTE:',np.bincount(y_trainfull))
X_train,y_train = classifier_utils.SMOTE_binary(X_train,y_train)
X_trainfull,y_trainfull = classifier_utils.SMOTE_binary(X_trainfull,y_trainfull)
print('binary, number of samples per class after SMOTE:',np.bincount(y_trainfull))
#multiclass
Xm_trainfull, Xm_test, ym_trainfull, ym_test = train_test_split(X, Ym, test_size=0.2, random_state=13)
Xm_train, Xm_valid, ym_train, ym_valid = train_test_split(Xm_trainfull, ym_trainfull, test_size = 0.2, random_state = 13)
print('multiclass, number of samples per class before SMOTE:',np.bincount(ym_trainfull+2))
Xm_train,ym_train = classifier_utils.SMOTE_multiclass(Xm_train,ym_train)
Xm_trainfull,ym_trainfull = classifier_utils.SMOTE_multiclass(Xm_trainfull,ym_trainfull)
print('multiclass, number of samples per class after SMOTE:',np.bincount(ym_trainfull+2))
# Out:
# 2017-08-24 09:12:02,975 : INFO : Compute classes statistics ...
# 2017-08-24 09:12:02,982 : INFO : 2 classes detected: Counter({0: 15281, 1: 3179})
# binary, number of samples per class before SMOTE: [19075  4001]
# 2017-08-24 09:12:03,498 : INFO : Generated 12102 new samples ...
# 2017-08-24 09:12:03,509 : INFO : Compute classes statistics ...
# 2017-08-24 09:12:03,515 : INFO : 2 classes detected: Counter({0: 19075, 1: 4001})
# 2017-08-24 09:12:04,239 : INFO : Generated 15074 new samples ...
# 2017-08-24 09:12:04,280 : INFO : Compute classes statistics ...
# 2017-08-24 09:12:04,286 : INFO : 7 classes detected: Counter({1: 7149, 2: 5476, 3: 3179, 0: 1687, 4: 394, -1: 371, -2: 204})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:12:04,369 : INFO : Generated 6945 new samples ...
# 2017-08-24 09:12:04,376 : INFO : Compute classes statistics ...
# 2017-08-24 09:12:04,384 : INFO : 7 classes detected: Counter({1: 7149, -2: 7149, 2: 5476, 3: 3179, 0: 1687, 4: 394, -1: 371})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# binary, number of samples per class after SMOTE: [19075 19075]
# multiclass, number of samples per class before SMOTE: [ 257  454 2090 8943 6836 4001  495]
# 2017-08-24 09:12:04,475 : INFO : Generated 6778 new samples ...
# 2017-08-24 09:12:04,486 : INFO : Compute classes statistics ...
# 2017-08-24 09:12:04,497 : INFO : 7 classes detected: Counter({1: 7149, -1: 7149, -2: 7149, 2: 5476, 3: 3179, 0: 1687, 4: 394})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:12:04,588 : INFO : Generated 6755 new samples ...
# 2017-08-24 09:12:04,609 : INFO : Compute classes statistics ...
# 2017-08-24 09:12:04,624 : INFO : 7 classes detected: Counter({1: 7149, 4: 7149, -1: 7149, -2: 7149, 2: 5476, 3: 3179, 0: 1687})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:12:04,822 : INFO : Generated 5462 new samples ...
# 2017-08-24 09:12:04,838 : INFO : Compute classes statistics ...
# 2017-08-24 09:12:04,850 : INFO : 7 classes detected: Counter({1: 7149, 0: 7149, 4: 7149, -1: 7149, -2: 7149, 2: 5476, 3: 3179})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:12:05,287 : INFO : Generated 3970 new samples ...
# 2017-08-24 09:12:05,304 : INFO : Compute classes statistics ...
# 2017-08-24 09:12:05,318 : INFO : 7 classes detected: Counter({1: 7149, 0: 7149, 3: 7149, 4: 7149, -1: 7149, -2: 7149, 2: 5476})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:12:06,395 : INFO : Generated 1673 new samples ...
# 2017-08-24 09:12:06,416 : INFO : Compute classes statistics ...
# 2017-08-24 09:12:06,423 : INFO : 7 classes detected: Counter({1: 8943, 2: 6836, 3: 4001, 0: 2090, 4: 495, -1: 454, -2: 257})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:12:06,523 : INFO : Generated 8686 new samples ...
# 2017-08-24 09:12:06,528 : INFO : Compute classes statistics ...
# 2017-08-24 09:12:06,537 : INFO : 7 classes detected: Counter({1: 8943, -2: 8943, 2: 6836, 3: 4001, 0: 2090, 4: 495, -1: 454})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:12:06,646 : INFO : Generated 8489 new samples ...
# 2017-08-24 09:12:06,654 : INFO : Compute classes statistics ...
# 2017-08-24 09:12:06,665 : INFO : 7 classes detected: Counter({1: 8943, -1: 8943, -2: 8943, 2: 6836, 3: 4001, 0: 2090, 4: 495})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:12:06,787 : INFO : Generated 8448 new samples ...
# 2017-08-24 09:12:06,802 : INFO : Compute classes statistics ...
# 2017-08-24 09:12:06,817 : INFO : 7 classes detected: Counter({1: 8943, 4: 8943, -1: 8943, -2: 8943, 2: 6836, 3: 4001, 0: 2090})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:12:07,090 : INFO : Generated 6853 new samples ...
# 2017-08-24 09:12:07,108 : INFO : Compute classes statistics ...
# 2017-08-24 09:12:07,127 : INFO : 7 classes detected: Counter({1: 8943, 4: 8943, 0: 8943, -1: 8943, -2: 8943, 2: 6836, 3: 4001})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:12:07,753 : INFO : Generated 4942 new samples ...
# 2017-08-24 09:12:07,779 : INFO : Compute classes statistics ...
# 2017-08-24 09:12:07,797 : INFO : 7 classes detected: Counter({1: 8943, 3: 8943, 4: 8943, 0: 8943, -1: 8943, -2: 8943, 2: 6836})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:12:09,343 : INFO : Generated 2107 new samples ...
# multiclass, number of samples per class after SMOTE: [8943 8943 8943 8943 8943 8943 8943]

# %%
X_train.shape
# Out:
# (30562, 50)

# %% [markdown]
# # Random Forest - binary

# %%
#parameter selection on training and validation only
NUM_TREES = [10,20,30,40,50,100,150]#[30]
TREE_DEPTH = [2,5,8,10,12,20,30]#[10]#
classifier_utils.RF_binary_gridsearch(X_train,y_train,X_valid,y_valid,NUM_TREES,TREE_DEPTH)
# Out:
# 10 2
# Area Under Curve: 0.43
# 10 5
# Area Under Curve: 0.48
# 10 8
# Area Under Curve: 0.50
# 10 10
# Area Under Curve: 0.51
# 10 12
# Area Under Curve: 0.51
# 10 20
# Area Under Curve: 0.46
# 10 30
# Area Under Curve: 0.48
# 20 2
# Area Under Curve: 0.43
# 20 5
# Area Under Curve: 0.47
# 20 8
# Area Under Curve: 0.50
# 20 10
# Area Under Curve: 0.51
# 20 12
# Area Under Curve: 0.50
# 20 20
# Area Under Curve: 0.48
# 20 30
# Area Under Curve: 0.47
# 30 2
# Area Under Curve: 0.41
# 30 5
# Area Under Curve: 0.48
# 30 8
# Area Under Curve: 0.51
# 30 10
# Area Under Curve: 0.50
# 30 12
# Area Under Curve: 0.51
# 30 20
# Area Under Curve: 0.48
# 30 30
# Area Under Curve: 0.49
# 40 2
# Area Under Curve: 0.43
# 40 5
# Area Under Curve: 0.47
# 40 8
# Area Under Curve: 0.51
# 40 10
# Area Under Curve: 0.51
# 40 12
# Area Under Curve: 0.51
# 40 20
# Area Under Curve: 0.48
# 40 30
# Area Under Curve: 0.48
# 50 2
# Area Under Curve: 0.40
# 50 5
# Area Under Curve: 0.48
# 50 8
# Area Under Curve: 0.51
# 50 10
# Area Under Curve: 0.51
# 50 12
# Area Under Curve: 0.51
# 50 20
# Area Under Curve: 0.48
# 50 30
# Area Under Curve: 0.49
# 100 2
# Area Under Curve: 0.41
# 100 5
# Area Under Curve: 0.47
# 100 8
# Area Under Curve: 0.51
# 100 10
# Area Under Curve: 0.52
# 100 12
# Area Under Curve: 0.51
# 100 20
# Area Under Curve: 0.49
# 100 30
# Area Under Curve: 0.49
# 150 2
# Area Under Curve: 0.41
# 150 5
# Area Under Curve: 0.48
# 150 8
# Area Under Curve: 0.51
# 150 10
# Area Under Curve: 0.51
# 150 12
# Area Under Curve: 0.51
# 150 20
# Area Under Curve: 0.49
# 150 30
# Area Under Curve: 0.48

# %%
num_trees_optimal = 40
tree_depth_optimal = 8
classifier_utils.RF_binary_traintest(X_trainfull,y_trainfull,X_test,y_test,num_trees_optimal,tree_depth_optimal)
# Out:
# feature importance: [ 0.16063471  0.07998103  0.02012081  0.00965999  0.01435698  0.02098254
#   0.00430866  0.01216363  0.00741903  0.01032028  0.00958673  0.0096359
#   0.02537628  0.01865295  0.01031081  0.0262779   0.01008647  0.02951658
#   0.02638338  0.008294    0.00930858  0.00778123  0.01089843  0.01592045
#   0.00746782  0.00775801  0.01634912  0.00558102  0.08580397  0.00479874
#   0.01754851  0.00904343  0.01518396  0.00756238  0.0241971   0.00533147
#   0.02013819  0.00450752  0.00757818  0.00956596  0.01222358  0.00802306
#   0.01072944  0.04910041  0.00892671  0.04028976  0.01372713  0.00958741
#   0.00888624  0.03211354]
# accuracy: 0.733968804159
# precision: 0.368396001904
# recall: 0.788187372709
# f1: 0.502108336036
# Normalized confusion matrix
# [[ 0.72  0.28]
#  [ 0.21  0.79]]
# Confusion matrix, without normalization
# [[3461 1327]
#  [ 208  774]]

# %% [markdown]
# # Random Forest - multiclass

# %%
#parameter selection on training and validation only
NUM_TREES = [100,150,200,250]#[150]#
TREE_DEPTH = [10,20,30]#[20]#
classifier_utils.RF_multiclass_gridsearch(Xm_train,ym_train,Xm_valid,ym_valid,NUM_TREES,TREE_DEPTH)
# Out:
# 100 10
# 100 20
# 100 30
# 150 10
# 150 20
# 150 30
# 200 10
# 200 20
# 200 30
# 250 10
# 250 20
# 250 30

# %%
num_trees_optimal = 250
tree_depth_optimal = 30
classifier_utils.RF_multiclass_traintest(Xm_trainfull,ym_trainfull,Xm_test,ym_test,num_trees_optimal,tree_depth_optimal)
# Out:
# feature importance: [ 0.03  0.02  0.02  0.01  0.01  0.02  0.01  0.02  0.02  0.03  0.02  0.02
#   0.02  0.02  0.02  0.01  0.02  0.02  0.02  0.02  0.02  0.02  0.02  0.02
#   0.02  0.02  0.02  0.02  0.02  0.02  0.02  0.02  0.02  0.02  0.02  0.02
#   0.02  0.02  0.03  0.02  0.03  0.02  0.05  0.03  0.02  0.02  0.02  0.02
#   0.02  0.02]
# average precision score aka AUC PR curve: 0.580104954813
# accuracy: 0.490987868284
#              precision    recall  f1-score   support
#
#          -2       0.59      0.73      0.66        78
#          -1       0.19      0.37      0.25       120
#           0       0.28      0.24      0.26       539
#           1       0.69      0.48      0.57      2295
#           2       0.48      0.53      0.51      1640
#           3       0.44      0.60      0.51       982
#           4       0.17      0.37      0.23       116
#
# avg / total       0.53      0.49      0.50      5770
#
# Normalized confusion matrix
# [[ 0.73  0.03  0.06  0.04  0.08  0.03  0.04]
#  [ 0.    0.37  0.16  0.04  0.22  0.03  0.18]
#  [ 0.02  0.06  0.24  0.14  0.47  0.07  0.01]
#  [ 0.    0.01  0.05  0.48  0.22  0.2   0.03]
#  [ 0.01  0.05  0.09  0.13  0.53  0.13  0.05]
#  [ 0.01  0.02  0.03  0.18  0.11  0.6   0.05]
#  [ 0.01  0.1   0.08  0.12  0.17  0.15  0.37]]
# Confusion matrix, without normalization
# [[  57    2    5    3    6    2    3]
#  [   0   44   19    5   26    4   22]
#  [   9   30  131   75  252   36    6]
#  [   8   28  123 1098  516  463   59]
#  [  14   88  155  214  875  217   77]
#  [   7   23   34  173  110  585   50]
#  [   1   12    9   14   20   17   43]]

# %% [markdown]
# # Ridge Regression - binary

# %%
#parameter selection on training and validation only
LAMBDA_LIST = [0.1,1,10,100]
classifier_utils.LR_binary_lambdaselection(X_train,y_train,X_valid,y_valid,LAMBDA_LIST)
# Out:
# 0.1
# Area Under Curve: 0.48
# 1
# Area Under Curve: 0.48
# 10
# Area Under Curve: 0.48
# 100
# Area Under Curve: 0.48

# %%
lambda_optimal = 10
classifier_utils.LR_binary_traintest(X_trainfull,y_trainfull,X_test,y_test,lambda_optimal)
# Out:
# accuracy: 0.747487001733
# precision: 0.372517444981
# recall: 0.706720977597
# f1: 0.487873462214
# Normalized confusion matrix
# [[ 0.76  0.24]
#  [ 0.29  0.71]]
# Confusion matrix, without normalization
# [[3619 1169]
#  [ 288  694]]

# %% [markdown]
# # kNN - multiclass

# %%
#parameter selection on training and validation only
k_LIST = [20,30,50,80,100]
classifier_utils.kNN_multiclass_kselection(Xm_train,ym_train,Xm_valid,ym_valid,k_LIST)
# Out:
# 20
# 30
# 50
# 80
# 100

# %%
k_optimal = 80
classifier_utils.kNN_multiclass_traintest(Xm_trainfull,ym_trainfull,Xm_test,ym_test,k_optimal)
# Out:
# average precision score aka AUC PR curve: 0.548431105202
# accuracy: 0.403119584055
#              precision    recall  f1-score   support
#
#          -2       0.19      0.65      0.29        78
#          -1       0.11      0.58      0.19       120
#           0       0.23      0.23      0.23       539
#           1       0.71      0.37      0.49      2295
#           2       0.50      0.40      0.45      1640
#           3       0.41      0.52      0.46       982
#           4       0.11      0.53      0.18       116
#
# avg / total       0.52      0.40      0.43      5770
#
# Normalized confusion matrix
# [[ 0.65  0.14  0.05  0.03  0.03  0.01  0.09]
#  [ 0.09  0.58  0.1   0.02  0.06  0.    0.15]
#  [ 0.06  0.18  0.23  0.08  0.32  0.06  0.07]
#  [ 0.03  0.05  0.07  0.37  0.18  0.22  0.08]
#  [ 0.03  0.15  0.11  0.1   0.4   0.11  0.1 ]
#  [ 0.04  0.07  0.06  0.12  0.06  0.52  0.12]
#  [ 0.04  0.21  0.06  0.07  0.02  0.08  0.53]]
# Confusion matrix, without normalization
# [[ 51  11   4   2   2   1   7]
#  [ 11  70  12   2   7   0  18]
#  [ 30  98 126  42 173  31  39]
#  [ 77 105 163 843 416 516 175]
#  [ 54 242 182 167 661 177 157]
#  [ 42  69  61 116  62 514 118]
#  [  5  24   7   8   2   9  61]]
