# %%
#basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#function libraries
import load_data_utils
import parse_comments_utils
import features_utils
import classifier_utils
import plot_utils
from sklearn.model_selection import train_test_split
# Out:
# /anaconda/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
features = pd.read_pickle('./features')
labels = pd.read_pickle('./labels')

# %% [markdown]
# # SPLIT training, validation, testing set & SMOTE training set

# %%
X = features.as_matrix(features.columns[0:4])
Y = labels['purchase_intent'].astype(int)
Ym = labels['label'].astype(int)

#divide into trainig, validation & testing
#binary
X_trainfull, X_test, y_trainfull, y_test = train_test_split(X, Y, test_size=0.2, random_state=13)
X_train, X_valid, y_train, y_valid = train_test_split(X_trainfull, y_trainfull, test_size = 0.2, random_state = 13)
print('binary, number of samples per class before SMOTE:',np.bincount(y_trainfull))
X_train,y_train = classifier_utils.SMOTE_binary(X_train,y_train)
X_trainfull,y_trainfull = classifier_utils.SMOTE_binary(X_trainfull,y_trainfull)
print('binary, number of samples per class after SMOTE:',np.bincount(y_trainfull))
#multiclass
Xm_trainfull, Xm_test, ym_trainfull, ym_test = train_test_split(X, Ym, test_size=0.2, random_state=13)
Xm_train, Xm_valid, ym_train, ym_valid = train_test_split(Xm_trainfull, ym_trainfull, test_size = 0.2, random_state = 13)
print('multiclass, number of samples per class before SMOTE:',np.bincount(ym_trainfull+2))
Xm_train,ym_train = classifier_utils.SMOTE_multiclass(Xm_train,ym_train)
Xm_trainfull,ym_trainfull = classifier_utils.SMOTE_multiclass(Xm_trainfull,ym_trainfull)
print('multiclass, number of samples per class after SMOTE:',np.bincount(ym_trainfull+2))
# Out:
# 2017-08-24 09:13:24,224 : INFO : Compute classes statistics ...
# 2017-08-24 09:13:24,230 : INFO : 2 classes detected: Counter({0: 15281, 1: 3179})
# 2017-08-24 09:13:24,375 : INFO : Generated 12102 new samples ...
# 2017-08-24 09:13:24,377 : INFO : Compute classes statistics ...
# 2017-08-24 09:13:24,383 : INFO : 2 classes detected: Counter({0: 19075, 1: 4001})
# binary, number of samples per class before SMOTE: [19075  4001]
# 2017-08-24 09:13:24,553 : INFO : Generated 15074 new samples ...
# 2017-08-24 09:13:24,563 : INFO : Compute classes statistics ...
# 2017-08-24 09:13:24,569 : INFO : 7 classes detected: Counter({1: 7149, 2: 5476, 3: 3179, 0: 1687, 4: 394, -1: 371, -2: 204})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:13:24,646 : INFO : Generated 6945 new samples ...
# 2017-08-24 09:13:24,648 : INFO : Compute classes statistics ...
# 2017-08-24 09:13:24,656 : INFO : 7 classes detected: Counter({1: 7149, -2: 7149, 2: 5476, 3: 3179, 0: 1687, 4: 394, -1: 371})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:13:24,750 : INFO : Generated 6778 new samples ...
# 2017-08-24 09:13:24,751 : INFO : Compute classes statistics ...
# binary, number of samples per class after SMOTE: [19075 19075]
# multiclass, number of samples per class before SMOTE: [ 257  454 2090 8943 6836 4001  495]
# 2017-08-24 09:13:24,762 : INFO : 7 classes detected: Counter({1: 7149, -1: 7149, -2: 7149, 2: 5476, 3: 3179, 0: 1687, 4: 394})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:13:24,838 : INFO : Generated 6755 new samples ...
# 2017-08-24 09:13:24,840 : INFO : Compute classes statistics ...
# 2017-08-24 09:13:24,854 : INFO : 7 classes detected: Counter({1: 7149, 4: 7149, -1: 7149, -2: 7149, 2: 5476, 3: 3179, 0: 1687})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:13:24,920 : INFO : Generated 5462 new samples ...
# 2017-08-24 09:13:24,922 : INFO : Compute classes statistics ...
# 2017-08-24 09:13:24,933 : INFO : 7 classes detected: Counter({1: 7149, 0: 7149, 4: 7149, -1: 7149, -2: 7149, 2: 5476, 3: 3179})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:13:25,003 : INFO : Generated 3970 new samples ...
# 2017-08-24 09:13:25,005 : INFO : Compute classes statistics ...
# 2017-08-24 09:13:25,018 : INFO : 7 classes detected: Counter({1: 7149, 0: 7149, 3: 7149, 4: 7149, -1: 7149, -2: 7149, 2: 5476})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:13:25,126 : INFO : Generated 1673 new samples ...
# 2017-08-24 09:13:25,131 : INFO : Compute classes statistics ...
# 2017-08-24 09:13:25,137 : INFO : 7 classes detected: Counter({1: 8943, 2: 6836, 3: 4001, 0: 2090, 4: 495, -1: 454, -2: 257})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:13:25,227 : INFO : Generated 8686 new samples ...
# 2017-08-24 09:13:25,229 : INFO : Compute classes statistics ...
# 2017-08-24 09:13:25,240 : INFO : 7 classes detected: Counter({1: 8943, -2: 8943, 2: 6836, 3: 4001, 0: 2090, 4: 495, -1: 454})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:13:25,326 : INFO : Generated 8489 new samples ...
# 2017-08-24 09:13:25,327 : INFO : Compute classes statistics ...
# 2017-08-24 09:13:25,339 : INFO : 7 classes detected: Counter({1: 8943, -1: 8943, -2: 8943, 2: 6836, 3: 4001, 0: 2090, 4: 495})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:13:25,421 : INFO : Generated 8448 new samples ...
# 2017-08-24 09:13:25,423 : INFO : Compute classes statistics ...
# 2017-08-24 09:13:25,438 : INFO : 7 classes detected: Counter({1: 8943, 4: 8943, -1: 8943, -2: 8943, 2: 6836, 3: 4001, 0: 2090})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:13:25,528 : INFO : Generated 6853 new samples ...
# 2017-08-24 09:13:25,531 : INFO : Compute classes statistics ...
# 2017-08-24 09:13:25,546 : INFO : 7 classes detected: Counter({1: 8943, 4: 8943, 0: 8943, -1: 8943, -2: 8943, 2: 6836, 3: 4001})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:13:25,626 : INFO : Generated 4942 new samples ...
# 2017-08-24 09:13:25,629 : INFO : Compute classes statistics ...
# 2017-08-24 09:13:25,645 : INFO : 7 classes detected: Counter({1: 8943, 3: 8943, 4: 8943, 0: 8943, -1: 8943, -2: 8943, 2: 6836})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 09:13:25,802 : INFO : Generated 2107 new samples ...
# multiclass, number of samples per class after SMOTE: [8943 8943 8943 8943 8943 8943 8943]

# %%
X_train.shape
# Out:
# (30562, 4)

# %% [markdown]
# # Random Forest - binary

# %%
#parameter selection on training and validation only
NUM_TREES = [10,20,30,40,50,100,150]#[30]
TREE_DEPTH = [2,5,8,10,12,20,30]#[10]#
classifier_utils.RF_binary_gridsearch(X_train,y_train,X_valid,y_valid,NUM_TREES,TREE_DEPTH)
# Out:
# 10 2
# Area Under Curve: 0.44
# 10 5
# Area Under Curve: 0.44
# 10 8
# Area Under Curve: 0.45
# 10 10
# Area Under Curve: 0.45
# 10 12
# Area Under Curve: 0.42
# 10 20
# Area Under Curve: 0.37
# 10 30
# Area Under Curve: 0.36
# 20 2
# Area Under Curve: 0.43
# 20 5
# Area Under Curve: 0.44
# 20 8
# Area Under Curve: 0.45
# 20 10
# Area Under Curve: 0.44
# 20 12
# Area Under Curve: 0.44
# 20 20
# Area Under Curve: 0.38
# 20 30
# Area Under Curve: 0.36
# 30 2
# Area Under Curve: 0.44
# 30 5
# Area Under Curve: 0.45
# 30 8
# Area Under Curve: 0.45
# 30 10
# Area Under Curve: 0.44
# 30 12
# Area Under Curve: 0.43
# 30 20
# Area Under Curve: 0.39
# 30 30
# Area Under Curve: 0.37
# 40 2
# Area Under Curve: 0.44
# 40 5
# Area Under Curve: 0.45
# 40 8
# Area Under Curve: 0.45
# 40 10
# Area Under Curve: 0.44
# 40 12
# Area Under Curve: 0.44
# 40 20
# Area Under Curve: 0.38
# 40 30
# Area Under Curve: 0.37
# 50 2
# Area Under Curve: 0.44
# 50 5
# Area Under Curve: 0.45
# 50 8
# Area Under Curve: 0.45
# 50 10
# Area Under Curve: 0.45
# 50 12
# Area Under Curve: 0.44
# 50 20
# Area Under Curve: 0.38
# 50 30
# Area Under Curve: 0.37
# 100 2
# Area Under Curve: 0.44
# 100 5
# Area Under Curve: 0.45
# 100 8
# Area Under Curve: 0.45
# 100 10
# Area Under Curve: 0.45
# 100 12
# Area Under Curve: 0.44
# 100 20
# Area Under Curve: 0.39
# 100 30
# Area Under Curve: 0.37
# 150 2
# Area Under Curve: 0.44
# 150 5
# Area Under Curve: 0.45
# 150 8
# Area Under Curve: 0.45
# 150 10
# Area Under Curve: 0.45
# 150 12
# Area Under Curve: 0.43
# 150 20
# Area Under Curve: 0.39
# 150 30
# Area Under Curve: 0.37

# %%
num_trees_optimal = 50
tree_depth_optimal = 8
classifier_utils.RF_binary_traintest(X_trainfull,y_trainfull,X_test,y_test,num_trees_optimal,tree_depth_optimal)
# Out:
# feature importance: [ 0.47326612  0.11906129  0.34386637  0.06380622]
# accuracy: 0.724956672444
# precision: 0.337278106509
# recall: 0.63849287169
# f1: 0.441393875396
# Normalized confusion matrix
# [[ 0.74  0.26]
#  [ 0.36  0.64]]
# Confusion matrix, without normalization
# [[3556 1232]
#  [ 355  627]]

# %% [markdown]
# # Random Forest - multiclass

# %%
#parameter selection on training and validation only
NUM_TREES = [150,200,250,300]#[150]#
TREE_DEPTH = [5,8,10,20]#[20]#
classifier_utils.RF_multiclass_gridsearch(Xm_train,ym_train,Xm_valid,ym_valid,NUM_TREES,TREE_DEPTH)
# Out:
# 150 5
# 150 8
# 150 10
# 150 20
# 200 5
# 200 8
# 200 10
# 200 20
# 250 5
# 250 8
# 250 10
# 250 20
# 300 5
# 300 8
# 300 10
# 300 20

# %%
num_trees_optimal = 300
tree_depth_optimal = 5
classifier_utils.RF_multiclass_traintest(Xm_trainfull,ym_trainfull,Xm_test,ym_test,num_trees_optimal,tree_depth_optimal)
# Out:
# feature importance: [ 0.26  0.21  0.34  0.19]
# average precision score aka AUC PR curve: 0.495313976777
# accuracy: 0.298960138648
#              precision    recall  f1-score   support
#
#          -2       0.07      0.56      0.13        78
#          -1       0.13      0.51      0.21       120
#           0       0.11      0.40      0.17       539
#           1       0.65      0.26      0.37      2295
#           2       0.51      0.26      0.34      1640
#           3       0.42      0.38      0.40       982
#           4       0.08      0.07      0.07       116
#
# avg / total       0.49      0.30      0.34      5770
#
# Normalized confusion matrix
# [[ 0.56  0.08  0.27  0.03  0.    0.03  0.04]
#  [ 0.17  0.51  0.22  0.02  0.01  0.07  0.02]
#  [ 0.1   0.09  0.4   0.09  0.23  0.08  0.01]
#  [ 0.06  0.03  0.38  0.26  0.12  0.13  0.01]
#  [ 0.11  0.09  0.36  0.09  0.26  0.08  0.02]
#  [ 0.14  0.1   0.24  0.12  0.    0.38  0.02]
#  [ 0.22  0.12  0.29  0.05  0.    0.24  0.07]]
# Confusion matrix, without normalization
# [[ 44   6  21   2   0   2   3]
#  [ 20  61  26   2   1   8   2]
#  [ 52  51 214  49 123  42   8]
#  [141  79 867 602 272 303  31]
#  [175 144 590 154 421 127  29]
#  [136 101 234 114   4 375  18]
#  [ 26  14  34   6   0  28   8]]

# %% [markdown]
# # Ridge Regression - binary

# %%
#parameter selection on training and validation only
LAMBDA_LIST = [0.1,1,10,100]
classifier_utils.LR_binary_lambdaselection(X_train,y_train,X_valid,y_valid,LAMBDA_LIST)
# Out:
# 0.1
# Area Under Curve: 0.33
# 1
# Area Under Curve: 0.33
# 10
# Area Under Curve: 0.33
# 100
# Area Under Curve: 0.33

# %%
lambda_optimal = 10
classifier_utils.LR_binary_traintest(X_trainfull,y_trainfull,X_test,y_test,lambda_optimal)
# Out:
# accuracy: 0.665857885615
# precision: 0.288650580876
# recall: 0.65784114053
# f1: 0.401242236025
# Normalized confusion matrix
# [[ 0.67  0.33]
#  [ 0.34  0.66]]
# Confusion matrix, without normalization
# [[3196 1592]
#  [ 336  646]]

# %% [markdown]
# # kNN - multiclass

# %%
#parameter selection on training and validation only
k_LIST = [5,10,20,30,50,80]
classifier_utils.kNN_multiclass_kselection(Xm_train,ym_train,Xm_valid,ym_valid,k_LIST)
# Out:
# 5
# 10
# 20
# 30
# 50
# 80

# %%
k_optimal = 20
classifier_utils.kNN_multiclass_traintest(Xm_trainfull,ym_trainfull,Xm_test,ym_test,k_optimal)
# Out:
# average precision score aka AUC PR curve: 0.495518043143
# accuracy: 0.379029462738
#              precision    recall  f1-score   support
#
#          -2       0.22      0.37      0.27        78
#          -1       0.16      0.30      0.21       120
#           0       0.15      0.08      0.10       539
#           1       0.61      0.26      0.37      2295
#           2       0.36      0.67      0.47      1640
#           3       0.44      0.37      0.40       982
#           4       0.05      0.11      0.07       116
#
# avg / total       0.44      0.38      0.37      5770
#
# Normalized confusion matrix
# [[ 0.37  0.03  0.05  0.04  0.32  0.08  0.12]
#  [ 0.04  0.3   0.08  0.04  0.33  0.1   0.1 ]
#  [ 0.01  0.06  0.08  0.1   0.65  0.06  0.04]
#  [ 0.01  0.01  0.04  0.26  0.53  0.12  0.03]
#  [ 0.02  0.04  0.05  0.1   0.67  0.07  0.04]
#  [ 0.04  0.05  0.05  0.13  0.3   0.37  0.06]
#  [ 0.03  0.06  0.06  0.17  0.35  0.21  0.11]]
# Confusion matrix, without normalization
# [[  29    2    4    3   25    6    9]
#  [   5   36   10    5   40   12   12]
#  [   5   30   44   56  352   30   22]
#  [  24   33   97  599 1205  274   63]
#  [  26   71   87  169 1105  116   66]
#  [  41   48   52  126  299  361   55]
#  [   4    7    7   20   41   24   13]]
