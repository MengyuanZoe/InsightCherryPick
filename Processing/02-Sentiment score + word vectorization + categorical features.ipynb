# %%
#basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#function libraries
import load_data_utils
import parse_comments_utils
import features_utils
import classifier_utils
import plot_utils
from sklearn.model_selection import train_test_split
# Out:
# /anaconda/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
features = pd.read_pickle('./features')
labels = pd.read_pickle('./labels')

# %% [markdown]
# # SPLIT training, validation, testing set & SMOTE training set

# %%
X = features.as_matrix(features.columns[0:58])
Y = labels['purchase_intent'].astype(int)
Ym = labels['label'].astype(int)

#divide into trainig, validation & testing
#binary
X_trainfull, X_test, y_trainfull, y_test = train_test_split(X, Y, test_size=0.2, random_state=13)
X_train, X_valid, y_train, y_valid = train_test_split(X_trainfull, y_trainfull, test_size = 0.2, random_state = 13)
print('binary, number of samples per class before SMOTE:',np.bincount(y_trainfull))
X_train,y_train = classifier_utils.SMOTE_binary(X_train,y_train)
X_trainfull,y_trainfull = classifier_utils.SMOTE_binary(X_trainfull,y_trainfull)
print('binary, number of samples per class after SMOTE:',np.bincount(y_trainfull))
#multiclass
Xm_trainfull, Xm_test, ym_trainfull, ym_test = train_test_split(X, Ym, test_size=0.2, random_state=13)
Xm_train, Xm_valid, ym_train, ym_valid = train_test_split(Xm_trainfull, ym_trainfull, test_size = 0.2, random_state = 13)
print('multiclass, number of samples per class before SMOTE:',np.bincount(ym_trainfull+2))
Xm_train,ym_train = classifier_utils.SMOTE_multiclass(Xm_train,ym_train)
Xm_trainfull,ym_trainfull = classifier_utils.SMOTE_multiclass(Xm_trainfull,ym_trainfull)
print('multiclass, number of samples per class after SMOTE:',np.bincount(ym_trainfull+2))
# Out:
# 2017-08-24 08:59:47,279 : INFO : Compute classes statistics ...
# 2017-08-24 08:59:47,284 : INFO : 2 classes detected: Counter({0: 15281, 1: 3179})
# binary, number of samples per class before SMOTE: [19075  4001]
# 2017-08-24 08:59:47,826 : INFO : Generated 12102 new samples ...
# 2017-08-24 08:59:47,834 : INFO : Compute classes statistics ...
# 2017-08-24 08:59:47,840 : INFO : 2 classes detected: Counter({0: 19075, 1: 4001})
# 2017-08-24 08:59:48,598 : INFO : Generated 15074 new samples ...
# 2017-08-24 08:59:48,642 : INFO : Compute classes statistics ...
# 2017-08-24 08:59:48,648 : INFO : 7 classes detected: Counter({1: 7149, 2: 5476, 3: 3179, 0: 1687, 4: 394, -1: 371, -2: 204})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 08:59:48,724 : INFO : Generated 6945 new samples ...
# 2017-08-24 08:59:48,730 : INFO : Compute classes statistics ...
# 2017-08-24 08:59:48,737 : INFO : 7 classes detected: Counter({1: 7149, -2: 7149, 2: 5476, 3: 3179, 0: 1687, 4: 394, -1: 371})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# binary, number of samples per class after SMOTE: [19075 19075]
# multiclass, number of samples per class before SMOTE: [ 257  454 2090 8943 6836 4001  495]
# 2017-08-24 08:59:48,837 : INFO : Generated 6778 new samples ...
# 2017-08-24 08:59:48,845 : INFO : Compute classes statistics ...
# 2017-08-24 08:59:48,855 : INFO : 7 classes detected: Counter({1: 7149, -1: 7149, -2: 7149, 2: 5476, 3: 3179, 0: 1687, 4: 394})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 08:59:48,942 : INFO : Generated 6755 new samples ...
# 2017-08-24 08:59:48,951 : INFO : Compute classes statistics ...
# 2017-08-24 08:59:48,962 : INFO : 7 classes detected: Counter({1: 7149, 4: 7149, -1: 7149, -2: 7149, 2: 5476, 3: 3179, 0: 1687})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 08:59:49,158 : INFO : Generated 5462 new samples ...
# 2017-08-24 08:59:49,168 : INFO : Compute classes statistics ...
# 2017-08-24 08:59:49,180 : INFO : 7 classes detected: Counter({1: 7149, 0: 7149, 4: 7149, -1: 7149, -2: 7149, 2: 5476, 3: 3179})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 08:59:49,584 : INFO : Generated 3970 new samples ...
# 2017-08-24 08:59:49,595 : INFO : Compute classes statistics ...
# 2017-08-24 08:59:49,608 : INFO : 7 classes detected: Counter({1: 7149, 0: 7149, 3: 7149, 4: 7149, -1: 7149, -2: 7149, 2: 5476})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 08:59:50,787 : INFO : Generated 1673 new samples ...
# 2017-08-24 08:59:50,801 : INFO : Compute classes statistics ...
# 2017-08-24 08:59:50,809 : INFO : 7 classes detected: Counter({1: 8943, 2: 6836, 3: 4001, 0: 2090, 4: 495, -1: 454, -2: 257})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 08:59:50,905 : INFO : Generated 8686 new samples ...
# 2017-08-24 08:59:50,911 : INFO : Compute classes statistics ...
# 2017-08-24 08:59:50,921 : INFO : 7 classes detected: Counter({1: 8943, -2: 8943, 2: 6836, 3: 4001, 0: 2090, 4: 495, -1: 454})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 08:59:51,030 : INFO : Generated 8489 new samples ...
# 2017-08-24 08:59:51,047 : INFO : Compute classes statistics ...
# 2017-08-24 08:59:51,059 : INFO : 7 classes detected: Counter({1: 8943, -1: 8943, -2: 8943, 2: 6836, 3: 4001, 0: 2090, 4: 495})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 08:59:51,175 : INFO : Generated 8448 new samples ...
# 2017-08-24 08:59:51,186 : INFO : Compute classes statistics ...
# 2017-08-24 08:59:51,200 : INFO : 7 classes detected: Counter({1: 8943, 4: 8943, -1: 8943, -2: 8943, 2: 6836, 3: 4001, 0: 2090})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 08:59:51,489 : INFO : Generated 6853 new samples ...
# 2017-08-24 08:59:51,508 : INFO : Compute classes statistics ...
# 2017-08-24 08:59:51,524 : INFO : 7 classes detected: Counter({1: 8943, 4: 8943, 0: 8943, -1: 8943, -2: 8943, 2: 6836, 3: 4001})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 08:59:52,202 : INFO : Generated 4942 new samples ...
# 2017-08-24 08:59:52,221 : INFO : Compute classes statistics ...
# 2017-08-24 08:59:52,239 : INFO : 7 classes detected: Counter({1: 8943, 3: 8943, 4: 8943, 0: 8943, -1: 8943, -2: 8943, 2: 6836})
# /anaconda/lib/python3.6/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# 2017-08-24 08:59:53,981 : INFO : Generated 2107 new samples ...
# multiclass, number of samples per class after SMOTE: [8943 8943 8943 8943 8943 8943 8943]

# %% [markdown]
# # Random Forest - binary

# %%
#parameter selection on training and validation only
NUM_TREES = [10,20,30,40,50,100,150]#[30]
TREE_DEPTH = [2,5,8,10,12,20,30]#[10]#
classifier_utils.RF_binary_gridsearch(X_train,y_train,X_valid,y_valid,NUM_TREES,TREE_DEPTH)
# Out:
# 10 2
# Area Under Curve: 0.52
# 10 5
# Area Under Curve: 0.58
# 10 8
# Area Under Curve: 0.63
# 10 10
# Area Under Curve: 0.64
# 10 12
# Area Under Curve: 0.61
# 10 20
# Area Under Curve: 0.60
# 10 30
# Area Under Curve: 0.60
# 20 2
# Area Under Curve: 0.52
# 20 5
# Area Under Curve: 0.60
# 20 8
# Area Under Curve: 0.65
# 20 10
# Area Under Curve: 0.65
# 20 12
# Area Under Curve: 0.66
# 20 20
# Area Under Curve: 0.63
# 20 30
# Area Under Curve: 0.62
# 30 2
# Area Under Curve: 0.53
# 30 5
# Area Under Curve: 0.63
# 30 8
# Area Under Curve: 0.65
# 30 10
# Area Under Curve: 0.66
# 30 12
# Area Under Curve: 0.66
# 30 20
# Area Under Curve: 0.64
# 30 30
# Area Under Curve: 0.62
# 40 2
# Area Under Curve: 0.55
# 40 5
# Area Under Curve: 0.63
# 40 8
# Area Under Curve: 0.65
# 40 10
# Area Under Curve: 0.66
# 40 12
# Area Under Curve: 0.66
# 40 20
# Area Under Curve: 0.64
# 40 30
# Area Under Curve: 0.62
# 50 2
# Area Under Curve: 0.52
# 50 5
# Area Under Curve: 0.62
# 50 8
# Area Under Curve: 0.66
# 50 10
# Area Under Curve: 0.66
# 50 12
# Area Under Curve: 0.66
# 50 20
# Area Under Curve: 0.64
# 50 30
# Area Under Curve: 0.62
# 100 2
# Area Under Curve: 0.53
# 100 5
# Area Under Curve: 0.63
# 100 8
# Area Under Curve: 0.65
# 100 10
# Area Under Curve: 0.66
# 100 12
# Area Under Curve: 0.67
# 100 20
# Area Under Curve: 0.64
# 100 30
# Area Under Curve: 0.63
# 150 2
# Area Under Curve: 0.53
# 150 5
# Area Under Curve: 0.63
# 150 8
# Area Under Curve: 0.65
# 150 10
# Area Under Curve: 0.66
# 150 12
# Area Under Curve: 0.66
# 150 20
# Area Under Curve: 0.65
# 150 30
# Area Under Curve: 0.63

# %%
num_trees_optimal = 100
tree_depth_optimal = 12
classifier_utils.RF_binary_traintest(X_trainfull,y_trainfull,X_test,y_test,num_trees_optimal,tree_depth_optimal)
# Out:
# feature importance: [ 0.04652749  0.01269674  0.0297291   0.00330534  0.00499713  0.00231027
#   0.08502848  0.14443464  0.07526878  0.04470828  0.02075232  0.00876867
#   0.00907913  0.02482378  0.00758047  0.01143835  0.01364599  0.00906752
#   0.00808731  0.00998661  0.01729937  0.00984149  0.00822993  0.00795183
#   0.00828168  0.00903621  0.01275075  0.008523    0.01141609  0.00824763
#   0.0070554   0.01662586  0.00712983  0.00982649  0.0124342   0.00829877
#   0.02305089  0.00737749  0.01413488  0.01131925  0.00915618  0.00760052
#   0.01702867  0.00780995  0.01122384  0.00598984  0.00683796  0.00891908
#   0.00915455  0.00929875  0.01266927  0.03086614  0.00842987  0.01961414
#   0.00869822  0.00819911  0.01424853  0.01318793]
# accuracy: 0.833968804159
# precision: 0.508119079838
# recall: 0.764765784114
# f1: 0.610569105691
# Normalized confusion matrix
# [[ 0.85  0.15]
#  [ 0.24  0.76]]
# Confusion matrix, without normalization
# [[4061  727]
#  [ 231  751]]

# %% [markdown]
# # Random Forest - multiclass

# %%
#parameter selection on training and validation only
NUM_TREES = [100,150,200,250]#[150]#
TREE_DEPTH = [10,20,30]#[20]#
classifier_utils.RF_multiclass_gridsearch(Xm_train,ym_train,Xm_valid,ym_valid,NUM_TREES,TREE_DEPTH)
# Out:
# 100 10
# 100 20
# 100 30
# 150 10
# 150 20
# 150 30
# 200 10
# 200 20
# 200 30
# 250 10
# 250 20
# 250 30

# %%
num_trees_optimal = 200
tree_depth_optimal = 20
classifier_utils.RF_multiclass_traintest(Xm_trainfull,ym_trainfull,Xm_test,ym_test,num_trees_optimal,tree_depth_optimal)
# Out:
# feature importance: [ 0.0275598   0.01536458  0.01804581  0.01759445  0.00621102  0.00803184
#   0.04462433  0.03595067  0.02584201  0.01718177  0.01416391  0.01163747
#   0.0120762   0.014508    0.01011761  0.01504111  0.01924175  0.02906345
#   0.01523438  0.01853272  0.01383451  0.01507005  0.01668376  0.01263367
#   0.01438652  0.01304827  0.01857922  0.01591914  0.01325646  0.01235594
#   0.01180002  0.014505    0.01258115  0.01207982  0.01235359  0.01996792
#   0.01492658  0.01474414  0.01750108  0.01589829  0.01789415  0.01239516
#   0.01397651  0.02182816  0.02069996  0.02077605  0.02067033  0.01677894
#   0.02217428  0.01644229  0.03969056  0.02286011  0.01714414  0.01466792
#   0.01263861  0.01190628  0.01548911  0.01381941]
# average precision score aka AUC PR curve: 0.664144863473
# accuracy: 0.582842287695
#              precision    recall  f1-score   support
#
#          -2       0.66      0.74      0.70        78
#          -1       0.26      0.59      0.36       120
#           0       0.31      0.27      0.29       539
#           1       0.81      0.52      0.63      2295
#           2       0.59      0.73      0.65      1640
#           3       0.56      0.67      0.61       982
#           4       0.20      0.43      0.28       116
#
# avg / total       0.63      0.58      0.59      5770
#
# Normalized confusion matrix
# [[ 0.74  0.05  0.05  0.05  0.05  0.03  0.03]
#  [ 0.    0.59  0.11  0.06  0.13  0.02  0.09]
#  [ 0.01  0.08  0.27  0.09  0.46  0.06  0.01]
#  [ 0.    0.02  0.06  0.52  0.21  0.17  0.03]
#  [ 0.01  0.05  0.08  0.05  0.73  0.05  0.03]
#  [ 0.01  0.03  0.03  0.12  0.09  0.67  0.05]
#  [ 0.01  0.11  0.09  0.12  0.09  0.16  0.43]]
# Confusion matrix, without normalization
# [[  58    4    4    4    4    2    2]
#  [   0   71   13    7   16    2   11]
#  [   8   45  148   48  250   32    8]
#  [   6   40  135 1184  475  386   69]
#  [   9   78  133   85 1195   85   55]
#  [   6   27   29  121   90  657   52]
#  [   1   13   10   14   10   18   50]]

# %% [markdown]
# # Ridge Regression - binary

# %%
#parameter selection on training and validation only
LAMBDA_LIST = [0.1,1,10,100]
classifier_utils.LR_binary_lambdaselection(X_train,y_train,X_valid,y_valid,LAMBDA_LIST)
# Out:
# 0.1
# Area Under Curve: 0.58
# 1
# Area Under Curve: 0.59
# 10
# Area Under Curve: 0.59
# 100
# Area Under Curve: 0.59

# %%
lambda_optimal = 10
classifier_utils.LR_binary_traintest(X_trainfull,y_trainfull,X_test,y_test,lambda_optimal)
# Out:
# accuracy: 0.774350086655
# precision: 0.415254237288
# recall: 0.798370672098
# f1: 0.546341463415
# Normalized confusion matrix
# [[ 0.77  0.23]
#  [ 0.2   0.8 ]]
# Confusion matrix, without normalization
# [[3684 1104]
#  [ 198  784]]

# %% [markdown]
# # kNN - multiclass

# %%
#parameter selection on training and validation only
k_LIST = [20,30,50,80]
classifier_utils.kNN_multiclass_kselection(Xm_train,ym_train,Xm_valid,ym_valid,k_LIST)

# %%
k_optimal = 50
classifier_utils.kNN_multiclass_traintest(Xm_trainfull,ym_trainfull,Xm_test,ym_test,k_optimal)
# Out:
# average precision score aka AUC PR curve: 0.625373271749
# accuracy: 0.491334488735
#              precision    recall  f1-score   support
#
#          -2       0.26      0.68      0.38        78
#          -1       0.13      0.62      0.22       120
#           0       0.22      0.25      0.23       539
#           1       0.83      0.45      0.59      2295
#           2       0.58      0.62      0.60      1640
#           3       0.58      0.47      0.52       982
#           4       0.09      0.43      0.14       116
#
# avg / total       0.62      0.49      0.53      5770
#
# Normalized confusion matrix
# [[ 0.68  0.08  0.05  0.04  0.04  0.    0.12]
#  [ 0.07  0.62  0.1   0.02  0.05  0.    0.15]
#  [ 0.03  0.15  0.25  0.08  0.37  0.04  0.08]
#  [ 0.02  0.05  0.08  0.45  0.19  0.11  0.09]
#  [ 0.02  0.1   0.14  0.03  0.62  0.02  0.07]
#  [ 0.04  0.1   0.05  0.12  0.08  0.47  0.15]
#  [ 0.06  0.16  0.11  0.04  0.06  0.13  0.43]]
# Confusion matrix, without normalization
# [[  53    6    4    3    3    0    9]
#  [   8   74   12    2    6    0   18]
#  [  17   81  134   43  202   20   42]
#  [  51  110  178 1043  445  257  211]
#  [  27  168  223   51 1023   40  108]
#  [  38   97   50  117   77  458  145]
#  [   7   19   13    5    7   15   50]]
